# %%
import pandas as pd
import numpy as np
from sklearn import tree, metrics
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt
from io import StringIO  
from IPython.display import Image  
# !pip install pydotplus 
import pydotplus 
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import SelectKBest, f_regression
import datetime

# %%
df2 = pd.read_excel(r'/Users/markclampitt/Documents/Springboard/Capstone2/Data\new_df.xlsx')

# %%
df2.head()
# Out:
#    Home Team Spread_x  Away Team Spread_x  Total_x  \
# 0                -2.5                 2.5     52.0
# 1                 6.5                -6.5     49.0
# 2                 6.5                -6.5     27.0
# 3                19.5               -19.5     55.5
# 4                31.5               -31.5     63.5
#
#    Rolling 5 Past H&A Score_Home_Team  Rolling 5 Past H&A Score Avg_Home_Team  \
# 0                               172.0                                    34.4
# 1                               187.0                                    37.4
# 2                               114.0                                    22.8
# 3                               123.0                                    24.6
# 4                                88.0                                    17.6
#
#    Rolling 5 Past H&A 1st Downs_Home_Team  \
# 0                                   119.0
# 1                                   118.0
# 2                                   100.0
# ...

# %%
df2.shape
# Out:
# (977, 41)

# %%
df2.describe()
# Out:
#        Home Team Spread_x  Away Team Spread_x     Total_x  \
# count          977.000000          977.000000  977.000000
# mean            -2.826510            2.826510   51.393040
# std             13.250883           13.250883    8.025355
# min            -41.500000          -36.000000   27.000000
# 25%            -12.500000           -6.500000   45.500000
# 50%             -3.000000            3.000000   50.500000
# 75%              6.500000           12.500000   56.000000
# max             36.000000           41.500000   82.500000
#
#        Rolling 5 Past H&A Score_Home_Team  \
# count                          942.000000
# mean                           127.528662
# std                             42.490716
# min                             33.000000
# 25%                             98.000000
# 50%                            124.000000
# 75%                            152.000000
# max                            261.000000
#
#        Rolling 5 Past H&A Score Avg_Home_Team  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 977 entries, 0 to 976
# Data columns (total 41 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Home Team Spread_x                               977 non-null    float64
#  1   Away Team Spread_x                               977 non-null    float64
#  2   Total_x                                          977 non-null    float64
#  3   Rolling 5 Past H&A Score_Home_Team               942 non-null    float64
#  4   Rolling 5 Past H&A Score Avg_Home_Team           942 non-null    float64
#  5   Rolling 5 Past H&A 1st Downs_Home_Team           936 non-null    float64
#  6   Rolling 5 Past H&A 1st Downs Avg_Home_Team       936 non-null    float64
#  7   Rolling 5 Past H&A Total Yards_Home_Team         936 non-null    float64
#  8   Rolling 5 Past H&A Total Yards Avg_Home_Team     936 non-null    float64
# ...

# %%
df3=df2.dropna()

# %%
df3.shape
# Out:
# (928, 41)

# %%
df3.isnull().sum().max()
# Out:
# 0

# %%
df3.describe()
# Out:
#        Home Team Spread_x  Away Team Spread_x     Total_x  \
# count          928.000000          928.000000  928.000000
# mean            -2.789332            2.789332   51.568966
# std             13.285394           13.285394    8.111918
# min            -41.500000          -36.000000   27.000000
# 25%            -12.500000           -6.500000   45.500000
# 50%             -3.000000            3.000000   50.500000
# 75%              6.500000           12.500000   56.500000
# max             36.000000           41.500000   82.500000
#
#        Rolling 5 Past H&A Score_Home_Team  \
# count                          928.000000
# mean                           127.842672
# std                             42.609400
# min                             33.000000
# 25%                             99.000000
# 50%                            124.000000
# 75%                            152.000000
# max                            261.000000
#
#        Rolling 5 Past H&A Score Avg_Home_Team  \
# ...

# %%
Team_Matchups = pd.DataFrame(columns=df3['Home Team'].unique(),index=df3['Home Team'].unique())

# %%
Team_Matchups
# Out:
#                   Alabama  LSU Auburn Vanderbilt Arkansas Mississippi State  \
# Alabama               NaN  NaN    NaN        NaN      NaN               NaN
# LSU                   NaN  NaN    NaN        NaN      NaN               NaN
# Auburn                NaN  NaN    NaN        NaN      NaN               NaN
# Vanderbilt            NaN  NaN    NaN        NaN      NaN               NaN
# Arkansas              NaN  NaN    NaN        NaN      NaN               NaN
# Mississippi State     NaN  NaN    NaN        NaN      NaN               NaN
# South Carolina        NaN  NaN    NaN        NaN      NaN               NaN
# Missouri              NaN  NaN    NaN        NaN      NaN               NaN
# Ole Miss              NaN  NaN    NaN        NaN      NaN               NaN
# Tennessee             NaN  NaN    NaN        NaN      NaN               NaN
# Kentucky              NaN  NaN    NaN        NaN      NaN               NaN
# ...

# %%
Row = 0
Column = 0

# %%
Teams=df3['Home Team'].unique()

# %%
Teams
# Out:
# array(['Alabama', 'LSU', 'Auburn', 'Vanderbilt', 'Arkansas',
#        'Mississippi State', 'South Carolina', 'Missouri', 'Ole Miss',
#        'Tennessee', 'Kentucky', 'Georgia', 'Texas A&M', 'Florida'],
#       dtype=object)

# %%
Teams2=Teams

# %%
Teams2
# Out:
# array(['Alabama', 'LSU', 'Auburn', 'Vanderbilt', 'Arkansas',
#        'Mississippi State', 'South Carolina', 'Missouri', 'Ole Miss',
#        'Tennessee', 'Kentucky', 'Georgia', 'Texas A&M', 'Florida'],
#       dtype=object)

# %%
Teams2[0]
# Out:
# 'Alabama'

# %%
Team_Matchups.iloc[0,1] =1
Team_Matchups
# Out:
#                   Alabama  LSU Auburn Vanderbilt Arkansas Mississippi State  \
# Alabama                 1    1    NaN        NaN      NaN               NaN
# LSU                   NaN  NaN    NaN        NaN      NaN               NaN
# Auburn                NaN  NaN    NaN        NaN      NaN               NaN
# Vanderbilt            NaN  NaN    NaN        NaN      NaN               NaN
# Arkansas              NaN  NaN    NaN        NaN      NaN               NaN
# Mississippi State     NaN  NaN    NaN        NaN      NaN               NaN
# South Carolina        NaN  NaN    NaN        NaN      NaN               NaN
# Missouri              NaN  NaN    NaN        NaN      NaN               NaN
# Ole Miss              NaN  NaN    NaN        NaN      NaN               NaN
# Tennessee             NaN  NaN    NaN        NaN      NaN               NaN
# Kentucky              NaN  NaN    NaN        NaN      NaN               NaN
# ...

# %%
df3[(df3['Home Team'] =='Alabama') & (df3['Away Team'] == 'LSU')]['Home Team'].count()
# Out:
# 9

# %%
df3[(df3['Away Team'] =='Alabama') & (df3['Home Team'] == 'LSU')]['Home Team'].count()
# Out:
# 9

# %%
df3[(df3['Home Team'] =='Alabama') & (df3['Away Team'] == 'LSU')]['Home Team'].count() + df3[(df3['Away Team'] =='Alabama') & (df3['Home Team'] == 'LSU')]['Home Team'].count()
# Out:
# 18

# %%
Row = 0
Column= 0
Start = 0
Stop = 15

# %%
while Column < Stop:
        Team_Matchups.iloc[Row,Column] = df3[(df3['Home Team'] ==Teams[Row]) & (df3['Away Team'] == Teams[Column])]['Home Team'].count() + df3[(df3['Away Team'] ==Teams[Row]) & (df3['Home Team'] == Teams[Column])]['Home Team'].count() 
        Column = Column + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-99-80f8386511ae> in <module>
#       1 while Column < Stop:
# ----> 2         Team_Matchups.iloc[Row,Column] = df3[(df3['Home Team'] ==Teams[Row]) & (df3['Away Team'] == Teams[Column])]['Home Team'].count() + df3[(df3['Away Team'] ==Teams[Row]) & (df3['Home Team'] == Teams[Column])]['Home Team'].count()
#       3         Column = Column + 1
#       4
#
# IndexError: index 14 is out of bounds for axis 0 with size 14

# %%
Row =1
Column =0
while Column < Stop:
        Team_Matchups.iloc[Row,Column] = df3[(df3['Home Team'] ==Teams[Row]) & (df3['Away Team'] == Teams[Column])]['Home Team'].count() + df3[(df3['Away Team'] ==Teams[Row]) & (df3['Home Team'] == Teams[Column])]['Home Team'].count() 
        Column = Column + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-100-2c5387f5ea0d> in <module>
#       2 Column =0
#       3 while Column < Stop:
# ----> 4         Team_Matchups.iloc[Row,Column] = df3[(df3['Home Team'] ==Teams[Row]) & (df3['Away Team'] == Teams[Column])]['Home Team'].count() + df3[(df3['Away Team'] ==Teams[Row]) & (df3['Home Team'] == Teams[Column])]['Home Team'].count()
#       5         Column = Column + 1
#
# IndexError: index 14 is out of bounds for axis 0 with size 14

# %%
Row =2
Column =0
while Column < Stop:
        Team_Matchups.iloc[Row,Column] = df3[(df3['Home Team'] ==Teams[Row]) & (df3['Away Team'] == Teams[Column])]['Home Team'].count() + df3[(df3['Away Team'] ==Teams[Row]) & (df3['Home Team'] == Teams[Column])]['Home Team'].count() 
        Column = Column + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-101-8599f0e120cb> in <module>
#       2 Column =0
#       3 while Column < Stop:
# ----> 4         Team_Matchups.iloc[Row,Column] = df3[(df3['Home Team'] ==Teams[Row]) & (df3['Away Team'] == Teams[Column])]['Home Team'].count() + df3[(df3['Away Team'] ==Teams[Row]) & (df3['Home Team'] == Teams[Column])]['Home Team'].count()
#       5         Column = Column + 1
#
# IndexError: index 14 is out of bounds for axis 0 with size 14

# %%
Row =3
Column =0
while Column < Stop:
        Team_Matchups.iloc[Row,Column] = df3[(df3['Home Team'] ==Teams[Row]) & (df3['Away Team'] == Teams[Column])]['Home Team'].count() + df3[(df3['Away Team'] ==Teams[Row]) & (df3['Home Team'] == Teams[Column])]['Home Team'].count() 
        Column = Column + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-102-cf78e283fc9b> in <module>
#       2 Column =0
#       3 while Column < Stop:
# ----> 4         Team_Matchups.iloc[Row,Column] = df3[(df3['Home Team'] ==Teams[Row]) & (df3['Away Team'] == Teams[Column])]['Home Team'].count() + df3[(df3['Away Team'] ==Teams[Row]) & (df3['Home Team'] == Teams[Column])]['Home Team'].count()
#       5         Column = Column + 1
#
# IndexError: index 14 is out of bounds for axis 0 with size 14

# %%
Row =4
Column =0
while Column < Stop:
        Team_Matchups.iloc[Row,Column] = df3[(df3['Home Team'] ==Teams[Row]) & (df3['Away Team'] == Teams[Column])]['Home Team'].count() + df3[(df3['Away Team'] ==Teams[Row]) & (df3['Home Team'] == Teams[Column])]['Home Team'].count() 
        Column = Column + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-103-db1a48e8ec4a> in <module>
#       2 Column =0
#       3 while Column < Stop:
# ----> 4         Team_Matchups.iloc[Row,Column] = df3[(df3['Home Team'] ==Teams[Row]) & (df3['Away Team'] == Teams[Column])]['Home Team'].count() + df3[(df3['Away Team'] ==Teams[Row]) & (df3['Home Team'] == Teams[Column])]['Home Team'].count()
#       5         Column = Column + 1
#
# IndexError: index 14 is out of bounds for axis 0 with size 14

# %%
Row =5
Column =0
while Column < Stop:
        Team_Matchups.iloc[Row,Column] = df3[(df3['Home Team'] ==Teams[Row]) & (df3['Away Team'] == Teams[Column])]['Home Team'].count() + df3[(df3['Away Team'] ==Teams[Row]) & (df3['Home Team'] == Teams[Column])]['Home Team'].count() 
        Column = Column + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-104-65fc43b108d2> in <module>
#       2 Column =0
#       3 while Column < Stop:
# ----> 4         Team_Matchups.iloc[Row,Column] = df3[(df3['Home Team'] ==Teams[Row]) & (df3['Away Team'] == Teams[Column])]['Home Team'].count() + df3[(df3['Away Team'] ==Teams[Row]) & (df3['Home Team'] == Teams[Column])]['Home Team'].count()
#       5         Column = Column + 1
#
# IndexError: index 14 is out of bounds for axis 0 with size 14

# %%
Row =6
Column =0
while Column < Stop:
        Team_Matchups.iloc[Row,Column] = df3[(df3['Home Team'] ==Teams[Row]) & (df3['Away Team'] == Teams[Column])]['Home Team'].count() + df3[(df3['Away Team'] ==Teams[Row]) & (df3['Home Team'] == Teams[Column])]['Home Team'].count() 
        Column = Column + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-105-2e6c164c16d3> in <module>
#       2 Column =0
#       3 while Column < Stop:
# ----> 4         Team_Matchups.iloc[Row,Column] = df3[(df3['Home Team'] ==Teams[Row]) & (df3['Away Team'] == Teams[Column])]['Home Team'].count() + df3[(df3['Away Team'] ==Teams[Row]) & (df3['Home Team'] == Teams[Column])]['Home Team'].count()
#       5         Column = Column + 1
#
# IndexError: index 14 is out of bounds for axis 0 with size 14

# %%
Row =7
Column =0
while Column < Stop:
        Team_Matchups.iloc[Row,Column] = df3[(df3['Home Team'] ==Teams[Row]) & (df3['Away Team'] == Teams[Column])]['Home Team'].count() + df3[(df3['Away Team'] ==Teams[Row]) & (df3['Home Team'] == Teams[Column])]['Home Team'].count() 
        Column = Column + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-106-8264ee9ef4db> in <module>
#       2 Column =0
#       3 while Column < Stop:
# ----> 4         Team_Matchups.iloc[Row,Column] = df3[(df3['Home Team'] ==Teams[Row]) & (df3['Away Team'] == Teams[Column])]['Home Team'].count() + df3[(df3['Away Team'] ==Teams[Row]) & (df3['Home Team'] == Teams[Column])]['Home Team'].count()
#       5         Column = Column + 1
#
# IndexError: index 14 is out of bounds for axis 0 with size 14

# %%
Row =8
Column =0
while Column < Stop:
        Team_Matchups.iloc[Row,Column] = df3[(df3['Home Team'] ==Teams[Row]) & (df3['Away Team'] == Teams[Column])]['Home Team'].count() + df3[(df3['Away Team'] ==Teams[Row]) & (df3['Home Team'] == Teams[Column])]['Home Team'].count() 
        Column = Column + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-107-5156d149ea01> in <module>
#       2 Column =0
#       3 while Column < Stop:
# ----> 4         Team_Matchups.iloc[Row,Column] = df3[(df3['Home Team'] ==Teams[Row]) & (df3['Away Team'] == Teams[Column])]['Home Team'].count() + df3[(df3['Away Team'] ==Teams[Row]) & (df3['Home Team'] == Teams[Column])]['Home Team'].count()
#       5         Column = Column + 1
#
# IndexError: index 14 is out of bounds for axis 0 with size 14

# %%
Row =9
Column =0
while Column < Stop:
        Team_Matchups.iloc[Row,Column] = df3[(df3['Home Team'] ==Teams[Row]) & (df3['Away Team'] == Teams[Column])]['Home Team'].count() + df3[(df3['Away Team'] ==Teams[Row]) & (df3['Home Team'] == Teams[Column])]['Home Team'].count() 
        Column = Column + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-108-9b865e8835a0> in <module>
#       2 Column =0
#       3 while Column < Stop:
# ----> 4         Team_Matchups.iloc[Row,Column] = df3[(df3['Home Team'] ==Teams[Row]) & (df3['Away Team'] == Teams[Column])]['Home Team'].count() + df3[(df3['Away Team'] ==Teams[Row]) & (df3['Home Team'] == Teams[Column])]['Home Team'].count()
#       5         Column = Column + 1
#
# IndexError: index 14 is out of bounds for axis 0 with size 14

# %%
Row =10
Column =0
while Column < Stop:
        Team_Matchups.iloc[Row,Column] = df3[(df3['Home Team'] ==Teams[Row]) & (df3['Away Team'] == Teams[Column])]['Home Team'].count() + df3[(df3['Away Team'] ==Teams[Row]) & (df3['Home Team'] == Teams[Column])]['Home Team'].count() 
        Column = Column + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-109-e6459f734d35> in <module>
#       2 Column =0
#       3 while Column < Stop:
# ----> 4         Team_Matchups.iloc[Row,Column] = df3[(df3['Home Team'] ==Teams[Row]) & (df3['Away Team'] == Teams[Column])]['Home Team'].count() + df3[(df3['Away Team'] ==Teams[Row]) & (df3['Home Team'] == Teams[Column])]['Home Team'].count()
#       5         Column = Column + 1
#
# IndexError: index 14 is out of bounds for axis 0 with size 14

# %%
Row =11
Column =0
while Column < Stop:
        Team_Matchups.iloc[Row,Column] = df3[(df3['Home Team'] ==Teams[Row]) & (df3['Away Team'] == Teams[Column])]['Home Team'].count() + df3[(df3['Away Team'] ==Teams[Row]) & (df3['Home Team'] == Teams[Column])]['Home Team'].count() 
        Column = Column + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-110-3482be823809> in <module>
#       2 Column =0
#       3 while Column < Stop:
# ----> 4         Team_Matchups.iloc[Row,Column] = df3[(df3['Home Team'] ==Teams[Row]) & (df3['Away Team'] == Teams[Column])]['Home Team'].count() + df3[(df3['Away Team'] ==Teams[Row]) & (df3['Home Team'] == Teams[Column])]['Home Team'].count()
#       5         Column = Column + 1
#
# IndexError: index 14 is out of bounds for axis 0 with size 14

# %%
Row =12
Column =0
while Column < Stop:
        Team_Matchups.iloc[Row,Column] = df3[(df3['Home Team'] ==Teams[Row]) & (df3['Away Team'] == Teams[Column])]['Home Team'].count() + df3[(df3['Away Team'] ==Teams[Row]) & (df3['Home Team'] == Teams[Column])]['Home Team'].count() 
        Column = Column + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-111-0ace032b3c15> in <module>
#       2 Column =0
#       3 while Column < Stop:
# ----> 4         Team_Matchups.iloc[Row,Column] = df3[(df3['Home Team'] ==Teams[Row]) & (df3['Away Team'] == Teams[Column])]['Home Team'].count() + df3[(df3['Away Team'] ==Teams[Row]) & (df3['Home Team'] == Teams[Column])]['Home Team'].count()
#       5         Column = Column + 1
#
# IndexError: index 14 is out of bounds for axis 0 with size 14

# %%
Row =13
Column =0
while Column < Stop:
        Team_Matchups.iloc[Row,Column] = df3[(df3['Home Team'] ==Teams[Row]) & (df3['Away Team'] == Teams[Column])]['Home Team'].count() + df3[(df3['Away Team'] ==Teams[Row]) & (df3['Home Team'] == Teams[Column])]['Home Team'].count() 
        Column = Column + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-112-e13dacde725c> in <module>
#       2 Column =0
#       3 while Column < Stop:
# ----> 4         Team_Matchups.iloc[Row,Column] = df3[(df3['Home Team'] ==Teams[Row]) & (df3['Away Team'] == Teams[Column])]['Home Team'].count() + df3[(df3['Away Team'] ==Teams[Row]) & (df3['Home Team'] == Teams[Column])]['Home Team'].count()
#       5         Column = Column + 1
#
# IndexError: index 14 is out of bounds for axis 0 with size 14

# %%
Row =14
Column =0
while Column < Stop:
        Team_Matchups.iloc[Row,Column] = df3[(df3['Home Team'] ==Teams[Row]) & (df3['Away Team'] == Teams[Column])]['Home Team'].count() + df3[(df3['Away Team'] ==Teams[Row]) & (df3['Home Team'] == Teams[Column])]['Home Team'].count() 
        Column = Column + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-113-720fac0f8dd6> in <module>
#       2 Column =0
#       3 while Column < Stop:
# ----> 4         Team_Matchups.iloc[Row,Column] = df3[(df3['Home Team'] ==Teams[Row]) & (df3['Away Team'] == Teams[Column])]['Home Team'].count() + df3[(df3['Away Team'] ==Teams[Row]) & (df3['Home Team'] == Teams[Column])]['Home Team'].count()
#       5         Column = Column + 1
#
# IndexError: index 14 is out of bounds for axis 0 with size 14

# %%
#Below shows the number of game matchups by teams. For example, there are 18 games of Alabama vs LSU.

# %%
Team_Matchups
# Out:
#                   Alabama LSU Auburn Vanderbilt Arkansas Mississippi State  \
# Alabama                 0  18     18          4       17                18
# LSU                    18   0     17          4       18                17
# Auburn                 18  17      0          4       17                17
# Vanderbilt              4   4      4          0        4                 5
# Arkansas               17  18     17          4        0                18
# Mississippi State      18  17     17          5       18                 0
# South Carolina          4   4      8         17       10                 5
# Missouri                3   2      2         10        8                 2
# Ole Miss               17  18     17         16       18                18
# Tennessee              16   6      6         17        5                 4
# Kentucky                5   5      5         18        4                16
# ...

# %%
df3[(df3['Home Team'] =='Kentucky') & (df3['Away Team'] == 'Tennessee')]['Home Team'].count() + df3[(df3['Away Team'] =='Kentucky') & (df3['Home Team'] == 'Tennessee')]['Home Team'].count()
# Out:
# 17

# %%
df3.dtypes
# Out:
# Home Team Spread_x                                        float64
# Away Team Spread_x                                        float64
# Total_x                                                   float64
# Rolling 5 Past H&A Score_Home_Team                        float64
# Rolling 5 Past H&A Score Avg_Home_Team                    float64
# Rolling 5 Past H&A 1st Downs_Home_Team                    float64
# Rolling 5 Past H&A 1st Downs Avg_Home_Team                float64
# Rolling 5 Past H&A Total Yards_Home_Team                  float64
# Rolling 5 Past H&A Total Yards Avg_Home_Team              float64
# Rolling 5 Past H&A Yards per Pass_Home_Team               float64
# Rolling 5 Past H&A Yards per Pass Avg_Home_Team           float64
# Rolling 5 Past H&A Spread_Home_Team                       float64
# Rolling 5 Past H&A Spread Avg_Home_Team                   float64
# Rolling 5 Past H&A Spread Min_Home_Team                   float64
# ...

# %%
for i in df3.columns:
    if df3[i].dtypes == 'float64':
        mean = df3[i].mean()
        std =df3[i].std()
        lower = mean + (-3 *std)
        upper = mean + (3*std)
        count = df3[(df3[i] > lower) & (df3[i] < upper)]['Home Team'].count()
        print('Feature:',i, "\n"' Rows: ', count,' Mean: ', mean,"\n" ' Std: ', std, ' Upper: ', upper,' Lower: ', lower, )
# Out:
# Feature: Home Team Spread_x
#  Rows:  928  Mean:  -2.789331896551724
#  Std:  13.285393768309849  Upper:  37.06684940837783  Lower:  -42.64551320148127
# Feature: Away Team Spread_x
#  Rows:  928  Mean:  2.789331896551724
#  Std:  13.285393768309849  Upper:  42.64551320148127  Lower:  -37.06684940837783
# Feature: Total_x
#  Rows:  922  Mean:  51.56896551724138
#  Std:  8.111918476332402  Upper:  75.90472094623858  Lower:  27.233210088244174
# Feature: Rolling 5 Past H&A Score_Home_Team
#  Rows:  926  Mean:  127.84267241379311
#  Std:  42.609400158266304  Upper:  255.67087288859202  Lower:  0.014471938994205402
# Feature: Rolling 5 Past H&A Score Avg_Home_Team
#  Rows:  926  Mean:  25.568534482758622
#  Std:  8.521880031653271  Upper:  51.13417457771844  Lower:  0.002894387798807685
# Feature: Rolling 5 Past H&A 1st Downs_Home_Team
#  Rows:  925  Mean:  98.25538793103448
#  Std:  17.716223863541337  Upper:  151.4040595216585  Lower:  45.106716340410465
# ...

# %%
# Out:
# [928,
#  928,
#  922,
#  926,
#  926,
#  925,
#  925,
#  928,
#  928,
#  924,
#  924,
#  926,
#  926,
#  928,
#  924,
#  924,
#  928,
#  925,
#  925,
#  925,
#  925,
#  926,
#  926,
#  925,
#  925,
#  927,
#  927,
#  928,
#  928,
#  927,
#  928,
#  927,
#  926,
#  927,
#  927]
